# %% [markdown]
# ## Describe Dataframe

# %%
import pandas as pd
piraten = pd.read_csv('piraten.txt', sep='\t')
print(piraten)
# Out:
#     pirat_in geschlecht  alter         meer  schaetze  schiffe  gefahr  \
# 0       Kurt          m   32.0      Karibik         4        0       1
# 1       Sven          m    NaN      Karibik         1        2       1
# 2      Sanna          w   35.0  Nordpazifik         4        3       1
# 3     Johnny          m   34.0  Nordpazifik         0        2       1
# 4   Annabell          w   39.0  Nordpazifik         1        2       1
# ..       ...        ...    ...          ...       ...      ...     ...
# 79       Tim          m   47.0      Nordsee         2        4       7
# 80  Walburga          w   38.0      Nordsee         7        5       8
# 81      Nina          w   28.0      Nordsee         0        4       8
# 82   Tjorven          w   35.0      Nordsee         2        7       8
# 83     Klaas          m   41.0      Nordsee         5        8       8
#
#    schwimmen besitzer_in
# 0        NaN        nein
# 1       nein        nein
# 2         ja          ja
# ...

# %%
print(round(piraten.describe()))
# Out:
#        alter  schaetze  schiffe  gefahr
# count   82.0      84.0     84.0    84.0
# mean    35.0       3.0      3.0     4.0
# std      8.0       3.0      2.0     2.0
# min     16.0       0.0      0.0     1.0
# 25%     30.0       1.0      2.0     3.0
# 50%     35.0       3.0      3.0     4.0
# 75%     39.0       4.0      4.0     5.0
# max     59.0      14.0      8.0     8.0

# %% [markdown]
# ## Select certain data

# %%
piraten[piraten['schwimmen'] == 'ja']
# Out:
#      pirat_in geschlecht  alter         meer  schaetze  schiffe  gefahr  \
# 2       Sanna          w   35.0  Nordpazifik         4        3       1
# 7     Randolf          m   35.0      Nordsee         8        0       1
# 9       Jenny          w   29.0      Karibik         3        1       2
# 15       Svea          w   29.0  Nordpazifik         1        3       2
# 16   Courtney          w   20.0      Karibik         2        3       3
# 19    Antonia          w   46.0      Karibik         3        1       3
# 22     Yannik          m   19.0  Nordpazifik         1        3       3
# 24       Tina          w   35.0  Nordpazifik         4        3       3
# 25      Bengt          m   36.0  Nordpazifik         1        3       3
# 31      Beate          w   28.0      Karibik         8        4       4
# 32      Conni          w   36.0      Karibik         1        2       4
# 34       Runi          w   44.0      Karibik         4        4       4
# ...
